# %%
import pandas as pd
import numpy as np

# %%
titanic=pd.read_csv(r"E:\Data Science\senapati\day33\New folder\TASK-13\DATASET\train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# ### now data cleaning & analysing strting from here
# - survived---> 1 or 0
# - passenger class --> 1st, 2nd , 3rd
# - SibSp---> number of siblings / spouses aboard
# - parch ---> number of parents / chidren aboard (some children travelled only with a nanny
# - cabin emabarked ---> port of embarkation (C=cherbourge, Q=queenstown, s=southampton)
# - (emabrked---> boarding station or point)

# %%
titanic.describe()
# stastical anlysis
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# deleted unwanted columns for effectice visualization & anylysis
del titanic['Name']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
del titanic['Ticket']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
del titanic['Fare']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0            1         0       3    male  22.0      1      0   NaN        S
# 1            2         1       1  female  38.0      1      0   C85        C
# 2            3         1       3  female  26.0      0      0   NaN        S
# 3            4         1       1  female  35.0      1      0  C123        S
# 4            5         0       3    male  35.0      0      0   NaN        S

# %%
del titanic['Cabin']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1         0       3    male  22.0      1      0        S
# 1            2         1       1  female  38.0      1      0        C
# 2            3         1       3  female  26.0      0      0        S
# 3            4         1       1  female  35.0      1      0        S
# 4            5         0       3    male  35.0      0      0        S

# %% [markdown]
# - now all unwanted columns

# %%
# Changing Value for "Male, Female" string values to numeric values , male=1 and female=2
def getnumber(str):
    if str=='male':
        return 1
    else:
        return 2
titanic['Gender']=titanic['Sex'].apply(getnumber)
#We have created a new column called "Gender" and 
#filling it with values 1,2 based on the values of sex column
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3    male  22.0      1      0        S       1
# 1            2         1       1  female  38.0      1      0        C       2
# 2            3         1       3  female  26.0      0      0        S       2
# 3            4         1       1  female  35.0      1      0        S       2
# 4            5         0       3    male  35.0      0      0        S       1

# %%
# deleting sex columns which replced by gender with having 1 or 2
del titanic['Sex']
titanic.head()
# deleted sex column which replaced by gender
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3  22.0      1      0        S       1
# 1            2         1       1  38.0      1      0        C       2
# 2            3         1       3  26.0      0      0        S       2
# 3            4         1       1  35.0      1      0        S       2
# 4            5         0       3  35.0      0      0        S       1

# %% [markdown]
# - here sex column was deleted

# %%
# we check for there is any null value or not
titanic.isnull().sum()
#  there is age having 177 & gender having 2 null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# dtype: int64

# %%
# now fill the null values of age column
avg=titanic[titanic.Survived==1].Age.mean()
# select the survived column having 1 value (alive)
# with refrence to age columns mean (avg)
# that means select age column with mean value(avg) having survived people

# %%
avg
# avg of age column having survived people
# Out:
# 28.343689655172415

# %%
titanic["age"]=np.where(pd.isnull(titanic.Age) & titanic["Survived"]==1  ,avg, titanic["Age"])
titanic.head()
# np.where() function is used to fill the "age" column
# pd.isnull(titanic.Age)--->This condition checks if the "Age" column has
## missing values (null values)
# & operator --->  Both conditions need to be true for the row to meet the criteria.
# titanic["Survived"]==1 ---> This condition checks if the "Survived" 
## column has a value of 1
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
missing_rows = titanic[titanic.isnull().any(axis=1)]
# print null values rows with columns notations

# %%
print(missing_rows)
# Out:
#      PassengerId  Survived  Pclass  Age  SibSp  Parch Embarked  Gender  \
# 5              6         0       3  NaN      0      0        Q       1
# 17            18         1       2  NaN      0      0        S       1
# 19            20         1       3  NaN      0      0        C       2
# 26            27         0       3  NaN      0      0        C       1
# 28            29         1       3  NaN      0      0        Q       2
# ..           ...       ...     ...  ...    ...    ...      ...     ...
# 859          860         0       3  NaN      0      0        C       1
# 863          864         0       3  NaN      8      2        S       2
# 868          869         0       3  NaN      0      0        S       1
# 878          879         0       3  NaN      0      0        S       1
# 888          889         0       3  NaN      1      2        S       2
#
#           age
# 5         NaN
# 17   28.34369
# 19   28.34369
# 26        NaN
# 28   28.34369
# ..        ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
titanic["age"]=np.where(pd.isnull(titanic.Age) & titanic["Survived"]==1  ,avg, titanic["Age"])
titanic.head()
# fill the bull value of survived peoples with mean value of age
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
titanic.isnull().sum()
# before age has 177 null values now it has reduced to 125
# means 52 null values are not survived people
# but remember that we created a new 'age' column & existing are also in dataset
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age            125
# dtype: int64

# %%
# Finding the mean age of "Not Survived" people
avgs=titanic[titanic.Survived==0].Age.mean()
avgs
# Out:
# 30.62617924528302

# %%
titanic.age.fillna(avgs, inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
titanic.isnull().sum()
# now age has no null value
# & now original 'Age' column has been need to deleted
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age              0
# dtype: int64

# %%
del titanic['Age']
titanic.head()
# orininal 'Age' column with many null values has been deleted
# & new age column are created with no null values
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %% [markdown]
# ### we want to check if embarked (boarding point or station or port) column is important for anlaysis or not, that is whether survival of the person depends on the embaked column value or not

# %%
# finidng the number of people who have survived
# given that they have embarked or boarded from perticular port

survivedQ=titanic[titanic.Embarked=='Q'][titanic.Survived==1].shape[0]
survivedC=titanic[titanic.Embarked=='C'][titanic.Survived==1].shape[0]
survivedS=titanic[titanic.Embarked=='S'][titanic.Survived==1].shape[0]
print(survivedQ)
print(survivedC)
print(survivedS)
# Out:
# 30
# 93
# 217
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_15312\3323349100.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedQ=titanic[titanic.Embarked=='Q'][titanic.Survived==1].shape[0]
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_15312\3323349100.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedC=titanic[titanic.Embarked=='C'][titanic.Survived==1].shape[0]
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_15312\3323349100.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedS=titanic[titanic.Embarked=='S'][titanic.Survived==1].shape[0]

# %% [markdown]
# - here are many value with survvied people in different port

# %%
# finding the number of people who had not survived (unwanted data)
# then unwanted data deleted iin further step

survivedQ=titanic[titanic.Embarked=='Q'][titanic.Survived==0].shape[0]
survivedC=titanic[titanic.Embarked=='C'][titanic.Survived==0].shape[0]
survivedS=titanic[titanic.Embarked=='S'][titanic.Survived==0].shape[0]
print(survivedQ)
print(survivedC)
print(survivedS)
# we cannot delted all embarked data column, now embaeked column has some
# null value & some usefull value
# hence we safely deleted null rows from total rows
# Out:
# 47
# 75
# 427
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_15312\2315437542.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedQ=titanic[titanic.Embarked=='Q'][titanic.Survived==0].shape[0]
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_15312\2315437542.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedC=titanic[titanic.Embarked=='C'][titanic.Survived==0].shape[0]
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_15312\2315437542.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedS=titanic[titanic.Embarked=='S'][titanic.Survived==0].shape[0]

# %%
# deleted null rows to clean the data
titanic.dropna(inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender        age
# 0              1         0       3      1      0        S       1  22.000000
# 1              2         1       1      1      0        C       2  38.000000
# 2              3         1       3      0      0        S       2  26.000000
# 3              4         1       1      1      0        S       2  35.000000
# 4              5         0       3      0      0        S       1  35.000000
# ..           ...       ...     ...    ...    ...      ...     ...        ...
# 886          887         0       2      0      0        S       1  27.000000
# 887          888         1       1      0      0        S       2  19.000000
# 888          889         0       3      1      2        S       2  30.626179
# 889          890         1       1      0      0        C       1  26.000000
# 890          891         0       3      0      0        Q       1  32.000000
#
# [889 rows x 8 columns]

# %%
titanic.isnull()
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch  Embarked  Gender    age
# 0          False     False   False  False  False     False   False  False
# 1          False     False   False  False  False     False   False  False
# 2          False     False   False  False  False     False   False  False
# 3          False     False   False  False  False     False   False  False
# 4          False     False   False  False  False     False   False  False
# ..           ...       ...     ...    ...    ...       ...     ...    ...
# 886        False     False   False  False  False     False   False  False
# 887        False     False   False  False  False     False   False  False
# 888        False     False   False  False  False     False   False  False
# 889        False     False   False  False  False     False   False  False
# 890        False     False   False  False  False     False   False  False
#
# [889 rows x 8 columns]

# %%
titanic.isnull().sum()
# now we said that the data is clean bcz no missing value in dataset
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# SibSp          0
# Parch          0
# Embarked       0
# Gender         0
# age            0
# dtype: int64

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
# renaming the elemnets of columns
titanic.rename(columns={'age':'Age'}, inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   Age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
titanic.rename(columns={'Gender':'Sex'}, inplace=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age
# 0            1         0       3      1      0        S    1  22.0
# 1            2         1       1      1      0        C    2  38.0
# 2            3         1       3      0      0        S    2  26.0
# 3            4         1       1      1      0        S    2  35.0
# 4            5         0       3      0      0        S    1  35.0

# %% [markdown]
# - here all dataset are in numeric format excluding E'mbarked' column we need to change string to numeric value

# %%
# apply numbers to embarked column for converting all string to numeric
def getemb(str):
    if str=='S':
        return 1
    elif str=='Q':
        return 2
    else:
        return 3
titanic['Embark']=titanic['Embarked'].apply(getemb)
titanic.head()
# we changed embarked column string to numeric
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age  Embark
# 0            1         0       3      1      0        S    1  22.0       1
# 1            2         1       1      1      0        C    2  38.0       3
# 2            3         1       3      0      0        S    2  26.0       1
# 3            4         1       1      1      0        S    2  35.0       1
# 4            5         0       3      0      0        S    1  35.0       1

# %%
del titanic['Embarked']
titanic.head()
# here orininal Embarked column is delted having str value
# new Embark column having numeric value
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch  Sex   Age  Embark
# 0            1         0       3      1      0    1  22.0       1
# 1            2         1       1      1      0    2  38.0       3
# 2            3         1       3      0      0    2  26.0       1
# 3            4         1       1      1      0    2  35.0       1
# 4            5         0       3      0      0    1  35.0       1

# %% [markdown]
# # visualization (pie- chart)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch  Sex   Age  Embark
# 0            1         0       3      1      0    1  22.0       1
# 1            2         1       1      1      0    2  38.0       3
# 2            3         1       3      0      0    2  26.0       1
# 3            4         1       1      1      0    2  35.0       1
# 4            5         0       3      0      0    1  35.0       1

# %%
#Drawing a pie chart for number of males and females aboard
import matplotlib.pyplot as plt
from matplotlib import style

males = (titanic['Sex'] == 1).sum() 
#Summing up all the values of column gender with a 
#condition for male and similary for females
females = (titanic['Sex'] == 2).sum()
print(males)
print(females)
p = [males, females]
plt.pie(p,    #giving array
       labels = ['Male', 'Female'], #Correspndingly giving labels
       colors = ['green', 'yellow'],   # Corresponding colors
       explode = (0.15, 0),    #How much the gap should me there between the pies
       startangle = 0)  #what start angle should be given
plt.axis('equal') 
plt.show()
# Out:
# 577
# 312

# %%
import matplotlib.pyplot as plt
from matplotlib import style
# more precise pie-chart
male=titanic[titanic.Sex==1][titanic.Survived==1].shape[0]
male1=titanic[titanic.Sex==1][titanic.Survived==0].shape[0]
female=titanic[titanic.Sex==2][titanic.Survived==1].shape[0]
female1=titanic[titanic.Sex==2][titanic.Survived==0].shape[0]
print(male)
print(male1)
print(female)
print(female1)
# Out:
# 109
# 468
# 231
# 81
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_15312\1450869578.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   male=titanic[titanic.Sex==1][titanic.Survived==1].shape[0]
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_15312\1450869578.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   male1=titanic[titanic.Sex==1][titanic.Survived==0].shape[0]
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_15312\1450869578.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female=titanic[titanic.Sex==2][titanic.Survived==1].shape[0]
# C:\Users\yogesh khairnar\AppData\Local\Temp\ipykernel_15312\1450869578.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female1=titanic[titanic.Sex==2][titanic.Survived==0].shape[0]

# %%
import matplotlib.pyplot as plt
from matplotlib import style
# make precise pie-chart
chart=[male,male1,female,female1]
colors=['lightskyblue','yellowgreen','Yellow','Orange']
labels=['Survived male','Not Survived Male','Survived Female','Not Survived Female']
explode=[0, 0.05, 0, 0.1]
plt.pie(chart, labels=labels, colors=colors, explode=explode,startangle=100, counterclock=False, autopct='%.2f%%')
plt.axis('equal')
plt.show()
